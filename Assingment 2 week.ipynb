# %%
#Question 1

import scipy.stats as stats

# Sample mean and standard deviation
sample_mean = 50
std_dev = 5

# Sample size (assuming a sufficiently large sample size for the use of the z-distribution)
sample_size = 100

# Calculate the standard error of the mean
standard_error = std_dev / (sample_size ** 0.5)

# Calculate the margin of error using the z-score for 95% confidence interval
z_score = stats.norm.ppf(0.975)  # for a two-tailed test
margin_of_error = z_score * standard_error

# Calculate the confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print("95% Confidence Interval:")
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# %%
#Question 2

from scipy import stats

# Observed counts of each color in the M&M bag
observed_counts = [30, 25, 20, 15, 10, 20]  # blue, orange, green, yellow, red, brown

# Expected percentages of each color
expected_percentages = [0.20, 0.20, 0.20, 0.10, 0.10, 0.20]

# Total number of M&Ms observed
total_observed = sum(observed_counts)

# Calculate expected counts based on the total observed and the expected percentages
expected_counts = [percentage * total_observed for percentage in expected_percentages]

# Perform the chi-square goodness of fit test
chi_sq_stat, p_value = stats.chisquare(observed_counts, expected_counts)

# Print the results
print("Chi-square statistic:", chi_sq_stat)
print("p-value:", p_value)

# Check significance level
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The observed distribution is significantly different from the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The observed distribution matches the expected distribution.")

# %%
#Question 4

import numpy as np
import scipy.stats as stats

# Sample size
n = 500

# Number of individuals who smoke
x = 60

# Calculate the proportion of smokers in the sample
p_hat = x / n

# Calculate the standard error of the proportion
standard_error = np.sqrt((p_hat * (1 - p_hat)) / n)

# Calculate the margin of error using the z-score for 95% confidence interval
z_score = stats.norm.ppf(0.975)  # for a two-tailed test
margin_of_error = z_score * standard_error

# Calculate the confidence interval
lower_bound = p_hat - margin_of_error
upper_bound = p_hat + margin_of_error

print("95% Confidence Interval for the proportion of smokers:")
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# %%
#Question 5 

import scipy.stats as stats

# Sample mean and standard deviation
sample_mean = 75
std_dev = 12

# Sample size (assuming a sufficiently large sample size for the use of the z-distribution)
sample_size = 100

# Calculate the standard error of the mean
standard_error = std_dev / (sample_size ** 0.5)

# Calculate the margin of error using the z-score for 90% confidence interval
z_score = stats.norm.ppf(0.95)  # for a two-tailed test
margin_of_error = z_score * standard_error

# Calculate the confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print("90% Confidence Interval:")
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# %%
#Question 6

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Degrees of freedom
df = 10

# Generate values for the chi-square distribution
x = np.linspace(0, 30, 1000)
y = stats.chi2.pdf(x, df)

# Plot the chi-square distribution
plt.plot(x, y, label='Chi-square Distribution (df=10)')

# Shade the area corresponding to a chi-square statistic of 15
x_fill = np.linspace(0, 15, 100)
y_fill = stats.chi2.pdf(x_fill, df)
plt.fill_between(x_fill, y_fill, color='blue', alpha=0.3, label='Chi-square Statistic = 15')

# Add labels and legend
plt.xlabel('Chi-square Statistic')
plt.ylabel('Probability Density')
plt.title('Chi-square Distribution with 10 Degrees of Freedom')
plt.legend()

# Show plot
plt.grid(True)
plt.show()

# %%
#Question 7

To calculate the 99% confidence interval for the true proportion of people in the population who prefer Coke, you can use the formula for the confidence interval of a proportion. The formula is:

CI
=
�
^
±
�
×
�
^
(
1
−
�
^
)
�
CI= 
p
^
​
 ±Z× 
n
p
^
​
 (1− 
p
^
​
 )
​
 
​
 

Where:

�
^
p
^
​
  is the sample proportion
�
Z is the Z-score corresponding to the desired confidence level
�
n is the sample size
Given that 
�
=
1000
n=1000, 
�
^
=
520
1000
=
0.52
p
^
​
 = 
1000
520
​
 =0.52, and we want a 99% confidence interval, we find the Z-score corresponding to the 99% confidence level. Then we can calculate the confidence interval using the formula.
  





import scipy.stats as stats

# Sample size
n = 1000

# Number of people who prefer Coke in the sample
x = 520

# Calculate the sample proportion
p_hat = x / n

# Calculate the Z-score for a 99% confidence level (two-tailed test)
Z = stats.norm.ppf(0.995)

# Calculate the margin of error
margin_of_error = Z * (p_hat * (1 - p_hat) / n) ** 0.5

# Calculate the confidence interval
lower_bound = p_hat - margin_of_error
upper_bound = p_hat + margin_of_error

print("99% Confidence Interval for the proportion of people who prefer Coke:")
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# %%
#Question 8

from scipy import stats

# Observed frequencies
observed_tails = 45
observed_heads = 100 - observed_tails

# Expected frequencies under the null hypothesis of a fair coin
expected_tails = 0.5 * 100
expected_heads = 0.5 * 100

# Calculate the chi-square statistic
chi_sq_stat = ((observed_tails - expected_tails) ** 2 / expected_tails) + ((observed_heads - expected_heads) ** 2 / expected_heads)

# Calculate the degrees of freedom
degrees_of_freedom = 1  # For a chi-square goodness of fit test with two categories (tails and heads), df = number of categories - 1

# Calculate the p-value
p_value = 1 - stats.chi2.cdf(chi_sq_stat, degrees_of_freedom)

# Significance level
alpha = 0.05

# Print the results
print("Chi-square statistic:", chi_sq_stat)
print("p-value:", p_value)

if p_value < alpha:
    print("Reject the null hypothesis: The observed frequencies do not match the expected frequencies of a fair coin.")
else:
    print("Fail to reject the null hypothesis: The observed frequencies match the expected frequencies of a fair coin.")

# %%
#Question 9
